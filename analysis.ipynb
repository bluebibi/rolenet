# %% [markdown]
# # Ch. 2 Introductory Examples

# %% [markdown]
# ## 1. usa.gov data from bit.ly

# %% [markdown]
# - 이미 웹에 저장되어 있는 txt 파일을 URL로 접근하여 가져오기 위하여 urllib2 모듈 활용

# %%
pathUrl = 'http://52.68.174.105/wp-content/uploads/2015/06/movies.csv'

# %%
import urllib2
from pandas import read_csv

# %%
raw_movie_data = urllib2.urlopen(pathUrl)

# %%
frame = read_csv(raw_movie_data)

# %%
frame[:]
# Out:
#       id                    name  year director  spectators  nodeCnt  \
# 0      1                7�ް�����  2009    ���¶�     4088799       22
# 1      2              7�����Ǽ���  2013    ��ȯ��    12811206       28
# 2      4               ������ź��  2006    ���¿�      221925       17
# 3      5                  ������  2006    ��ȯ��     1446820       20
# 4      6                   ��ö��  2008     ���켮     4300670       23
# 5      7                  �ŷ��Ѱ躸  2006     ����     1744677       25
# 6     10                     ���  2008    â����     1634051       22
# 7     11                  ������  2011     ����     2945137       23
# 8     12           �����̵�������  2005   ������     2430200        9
# 9     13                    ����  2012    ��â��    12319542       23
# 10    14                    ����  2006    ����ȣ    13019740       27
# 11    15                 ������ǥ  2009     ���ȭ     8487894       24
# 12    16           �׳ฦ����������  2004   ������     1204000       38
# 13    17                �׸��ڻ���  2009     �ڴ��     1914779       24
# 14    18                 ���ؿ���  2006    ���ٽ�      336065       26
# 15    20               ������ã��  2010   ������     1130638       22
# 16    21             ���Ǵº��̿���  2004   ������      717618       19
# 17    22            ���ǰ�ȥ������  2005    Ȳ����      767657       13
# 18    24           �����а�������  2010     �豤��      699973       23
# 19    26                 �ʴ³����  2005    ����ǥ     3051134       20
# 20    27          �����׳��������  2006   ������      434877       23
# 21    28          �����´��̿�����  2008   ������     2058764       24
# 22    29                �ټ����ҳ�  2006    �����      561803       38
# 23    31                 ���Ǽ���  2005    �ڿ���     2197555       15
# 24    32                   �����  2012    �̼���     4057546       32
# 25    33                  ������  2011    Ȳ����     4662822       23
# 26    34                   ���ϵ�  2012    �ֵ���    12983330       25
# 27    35            �������ļֶ�õ�  2008   ������      199151       12
# 28    36          ������������ϱ�  2003    �����     4937573       22
# 29    37                 ������Ÿ  2006   ������     1879501       17
# ..   ...                     ...   ...      ...         ...      ...
# 99   116          �츮�����ְ��Ǽ���  2008    �Ӽ���     4044582       21
# 100  118              ����������  2003   ������     2251491       24
# 101  120                   �Ƿ���  2011    �տ���     2393086       28
# 102  121                  ������  2010     ����     5507106       20
# 103  122                  ���߰�ø  2003   ������     1025928       20
# 104  124                   �ẹ�ٹ�  2005    �ڱ���     1914941       26
# 105  126               �����ǰ���  2007    ����ȯ      402117       15
# 106  127                    ����  1997   ������      674933       12
# 107  128               �����Ѽ���  2006    ���Ǽ�      178434       13
# 108  129              �����ƴ��Ѱ�  2007    ����ö      321654       21
# 109  130                  ��ȫ�۾�  2004     ����     1437549       15
# 110  131                     ��õ  2006   ������     1531220       15
# 111  132                 ��ſ��λ�  2007   ������     1263835       15
# 112  133             ���������Ѷ�  2003    ����ȯ       73132       20
# 113  134  ���ݻ���ϴ»��������ֽ��ϱ�  2007   ������     1095119       16
# 114  136             �����³�����  2003   ������       62788       21
# 115  137              õ����縶����  2006    ���ؿ�      678930       22
# 116  138               û��������  2012   ������        1600       13
# 117  139       ÿ��ȫ�����ϰ����λ��  2005     �̿�ö      197678       13
# 118  142                      Ÿ¥  2006    �ֵ���     6847777       39
# 119  143             �±ر��ֳ�����  2004   ������    11746135       31
# 120  145                   �ļ���  2011   ������       20885       13
# 121  148                 ǰ������  2002    ���ٽ�     1694637       28
# 122  149                 �ö��̴��  2006   ������      510604       17
# 123  151                    �ؾȼ�  2002     ����      123633       13
# 124  152                   ���Ǵ�  2005     ����     2274995       18
# 125  153           ȣ�κ��������Ͽ�  2006   ������      544656       17
# 126  154                 Ȧ������  2005    ����ȣ     1458896       24
# 127  155                ȫ�浿���Ŀ�  2009    �����      616654       18
# 128  156                ȿ�ڵ��̹߻�  2004   ������     1972377       31
#
#      diameter  pathlength  clustering   density     ...      \
# 0           3    1.753247    0.070402  0.307359     ...
# 1           3    1.825397    0.110300  0.277778     ...
# 2           3    1.985294    0.117503  0.279412     ...
# 3           5    2.068421    0.161326  0.257895     ...
# 4           3    1.822134    0.132806  0.264822     ...
# 5           4    1.916667    0.108131  0.283333     ...
# 6           3    1.571429    0.107739  0.445887     ...
# 7           4    1.830040    0.072435  0.320158     ...
# 8           3    1.666667    0.222095  0.444444     ...
# 9           3    1.703557    0.072066  0.343874     ...
# 10          4    2.125356    0.102663  0.205128     ...
# 11          3    1.576087    0.079745  0.467391     ...
# 12          3    1.524893    0.067094  0.485064     ...
# 13          4    1.865942    0.074338  0.253623     ...
# 14          3    1.858462    0.081269  0.283077     ...
# 15          3    1.909091    0.077387  0.220779     ...
# 16          3    1.783626    0.135398  0.286550     ...
# 17          4    1.756410    0.081473  0.397436     ...
# 18          3    1.901186    0.118010  0.181818     ...
# 19          3    1.705263    0.092501  0.315789     ...
# 20          3    1.826087    0.135809  0.304348     ...
# 21          3    1.771739    0.131040  0.315217     ...
# 22          4    2.021337    0.081365  0.214794     ...
# 23          3    1.704762    0.066070  0.314286     ...
# 24          4    2.064516    0.079254  0.211694     ...
# 25          3    1.770751    0.076454  0.284585     ...
# 26          3    1.403333    0.141769  0.603333     ...
# 27          2    1.545455    0.095786  0.454545     ...
# 28          3    1.844156    0.053957  0.285714     ...
# 29          3    1.691176    0.072400  0.330882     ...
# ..        ...         ...         ...       ...     ...
# 99          3    1.671429    0.127581  0.414286     ...
# 100         3    1.887681    0.072507  0.221014     ...
# 101         4    2.105820    0.088093  0.206349     ...
# 102         3    1.736842    0.081205  0.305263     ...
# 103         3    1.878947    0.097363  0.252632     ...
# 104         4    1.996923    0.095853  0.258462     ...
# 105         3    1.838095    0.234689  0.352381     ...
# 106         4    2.166667    0.216987  0.242424     ...
# 107         3    1.705128    0.156407  0.397436     ...
# 108         3    1.876190    0.170984  0.271429     ...
# 109         2    1.742857    0.202730  0.257143     ...
# 110         3    1.695238    0.072019  0.342857     ...
# 111         3    1.923810    0.124458  0.257143     ...
# 112         4    2.005263    0.101628  0.252632     ...
# 113         3    1.525000    0.102502  0.516667     ...
# 114         4    1.914286    0.131392  0.323810     ...
# 115         3    1.956710    0.151947  0.216450     ...
# 116         4    1.961538    0.114256  0.269231     ...
# 117         2    1.589744    0.122202  0.410256     ...
# 118         3    1.894737    0.090299  0.203779     ...
# 119         4    1.840860    0.064836  0.258065     ...
# 120         3    1.833333    0.122712  0.358974     ...
# 121         4    2.042328    0.064628  0.219577     ...
# 122         2    1.551471    0.083364  0.448529     ...
# 123         3    1.448718    0.151834  0.564103     ...
# 124         3    1.581699    0.098853  0.437908     ...
# 125         3    1.794118    0.084245  0.250000     ...
# 126         3    1.673913    0.148347  0.384058     ...
# 127         4    1.875817    0.107795  0.359477     ...
# 128         3    2.010753    0.090012  0.189247     ...
#
#      betweennessTop_Others  betweennessVar  eigenvectorTop  \
# 0                 0.205238        0.004951        0.566626
# 1                 0.251440        0.005471        0.438859
# 2                 0.343403        0.015496        0.491826
# 3                 0.292793        0.007691        0.609414
# 4                 0.383370        0.007773        0.585898
# 5                 0.317469        0.005663        0.492713
# 6                 0.147888        0.002729        0.480414
# 7                 0.183997        0.003936        0.515444
# 8                 0.428571        0.022369        0.567492
# 9                 0.364628        0.006414        0.599529
# 10                0.528482        0.015722        0.547674
# 11                0.132749        0.001821        0.478657
# 12                0.270893        0.002036        0.495058
# 13                0.449115        0.009692        0.618644
# 14                0.313606        0.005726        0.562842
# 15                0.406349        0.014706        0.640194
# 16                0.549492        0.016059        0.664061
# 17                0.328199        0.012348        0.630349
# 18                0.565361        0.018303        0.653580
# 19                0.351493        0.009763        0.607181
# 20                0.160624        0.004450        0.559470
# 21                0.268938        0.004909        0.478554
# 22                0.473704        0.006618        0.450101
# 23                0.385400        0.016356        0.676491
# 24                0.271062        0.004985        0.580198
# 25                0.361084        0.007681        0.652319
# 26                0.093885        0.000696        0.427679
# 27                0.330579        0.010618        0.633523
# 28                0.323135        0.007838        0.622800
# 29                0.445694        0.014107        0.618751
# ..                     ...             ...             ...
# 99                0.203671        0.003815        0.490289
# 100               0.385255        0.012648        0.644808
# 101               0.314868        0.006389        0.614476
# 102               0.379091        0.009601        0.602665
# 103               0.433159        0.011797        0.646191
# 104               0.400500        0.007542        0.605092
# 105               0.253756        0.007597        0.571544
# 106               0.557025        0.049557        0.616326
# 107               0.386048        0.013149        0.540259
# 108               0.235539        0.007391        0.456827
# 109               0.759027        0.035973        0.655248
# 110               0.580455        0.022307        0.650726
# 111               0.483124        0.020911        0.573776
# 112               0.408023        0.010935        0.643189
# 113               0.130231        0.003241        0.532003
# 114               0.249000        0.005839        0.558018
# 115               0.507785        0.015174        0.641509
# 116               0.539983        0.026542        0.661526
# 117               0.511490        0.019798        0.601777
# 118               0.474765        0.006377        0.582488
# 119               0.400231        0.006999        0.555048
# 120               0.410354        0.017268        0.589901
# 121               0.424588        0.007179        0.622517
# 122               0.373626        0.008119        0.551233
# 123               0.195728        0.004003        0.529649
# 124               0.196744        0.004034        0.627119
# 125               0.646771        0.024167        0.663919
# 126               0.192612        0.002983        0.476801
# 127               0.221068        0.005910        0.563252
# 128               0.400705        0.007198        0.598151
#
#      eigenVectorTop_Others  eigenvectorVar  betweenness_centrality  \
# 0                 0.457560        0.028590                0.037662
# 1                 0.340986        0.023603                0.031746
# 2                 0.357356        0.034646                0.065686
# 3                 0.477908        0.025850                0.059357
# 4                 0.458529        0.021780                0.039149
# 5                 0.382004        0.024127                0.039855
# 6                 0.352761        0.024808                0.028571
# 7                 0.410882        0.028490                0.039526
# 8                 0.322781        0.032389                0.095238
# 9                 0.483393        0.024667                0.033503
# 10                0.455135        0.025070                0.045014
# 11                0.365591        0.025206                0.026186
# 12                0.392669        0.013609                0.014580
# 13                0.510805        0.024994                0.039361
# 14                0.446254        0.020572                0.035769
# 15                0.527427        0.026756                0.045455
# 16                0.521574        0.023753                0.046096
# 17                0.482190        0.042605                0.068765
# 18                0.549039        0.026989                0.042914
# 19                0.474875        0.025649                0.039181
# 20                0.432824        0.022318                0.039337
# 21                0.347044        0.020359                0.035079
# 22                0.355220        0.015452                0.028370
# 23                0.562815        0.043806                0.054212
# 24                0.489603        0.020036                0.035484
# 25                0.536595        0.024142                0.036702
# 26                0.279724        0.014673                0.017536
# 27                0.469066        0.041902                0.054545
# 28                0.515294        0.028312                0.042208
# 29                0.490350        0.034097                0.046078
# ..                     ...             ...                     ...
# 99                0.355154        0.024501                0.035338
# 100               0.531741        0.023381                0.040349
# 101               0.520581        0.023061                0.042532
# 102               0.483699        0.029508                0.040936
# 103               0.527994        0.029092                0.048830
# 104               0.496360        0.022123                0.041538
# 105               0.396819        0.026193                0.064469
# 106               0.440469        0.038150                0.116667
# 107               0.360769        0.033974                0.064103
# 108               0.329372        0.027130                0.046115
# 109               0.502790        0.032079                0.057143
# 110               0.517676        0.038590                0.053480
# 111               0.440748        0.040289                0.071062
# 112               0.539604        0.032953                0.055848
# 113               0.387366        0.033990                0.037500
# 114               0.429146        0.025326                0.048120
# 115               0.522538        0.025085                0.047835
# 116               0.519823        0.043912                0.087413
# 117               0.430088        0.034991                0.053613
# 118               0.492978        0.015206                0.024182
# 119               0.452343        0.018500                0.028995
# 120               0.437660        0.042362                0.075758
# 121               0.532437        0.023812                0.040090
# 122               0.410637        0.031680                0.036765
# 123               0.325482        0.024389                0.040793
# 124               0.477188        0.024424                0.036356
# 125               0.550827        0.037655                0.052941
# 126               0.349360        0.021503                0.030632
# 127               0.431513        0.031309                0.054739
# 128               0.507998        0.020907                0.034854
#
#      betweenness_centralityTop_Others  naverRole  betweenRole  degreeRole
# 0                            0.205238          2            3           4
# 1                            0.251440          8            2           6
# 2                            0.343403          7            2           6
# 3                            0.292793          2            1           1
# 4                            0.383370          2            1           1
# 5                            0.317469          2            1           1
# 6                            0.147888          4            3           5
# 7                            0.183997         11            6           3
# 8                            0.428571          5            1           1
# 9                            0.364628          6            1           1
# 10                           0.528482          5            2           3
# 11                           0.132749          7            1           7
# 12                           0.270893          2            1           1
# 13                           0.449115          4            1           2
# 14                           0.313606          2            2           3
# 15                           0.406349          2            2           2
# 16                           0.549492          1            1           1
# 17                           0.328199          3            1           2
# 18                           0.565361          2            2           1
# 19                           0.351493          3            2           2
# 20                           0.160624          5            5           1
# 21                           0.268938          2            2           3
# 22                           0.473704          3            1           9
# 23                           0.385400          2            2           2
# 24                           0.271062          2            1           2
# 25                           0.361084          2            2           1
# 26                           0.093885         10            1           1
# 27                           0.330579          3            1           1
# 28                           0.323135          2            2           2
# 29                           0.445694          2            1           2
# ..                                ...        ...          ...         ...
# 99                           0.203671          0            2           1
# 100                          0.385255          0            2           2
# 101                          0.314868          0            1           1
# 102                          0.379091          0            2           1
# 103                          0.433159          0            1           1
# 104                          0.400500          0            1           1
# 105                          0.253756          0            1           1
# 106                          0.557025          0            2           2
# 107                          0.386048          0            1           2
# 108                          0.235539          0            5           5
# 109                          0.759027          0            1           1
# 110                          0.580455          0            1           2
# 111                          0.483124          0            1           4
# 112                          0.408023          0            1           1
# 113                          0.130231          0            3           4
# 114                          0.249000          0            2           1
# 115                          0.507785          0            1           1
# 116                          0.539983          0            1           1
# 117                          0.511490          0            1           1
# 118                          0.474765          0            1           1
# 119                          0.400231          0            2           2
# 120                          0.410354          0            1           2
# 121                          0.424588          0            1           1
# 122                          0.373626          0            1           4
# 123                          0.195728          0            1           2
# 124                          0.196744          0            2           1
# 125                          0.646771          0            1           1
# 126                          0.192612          0            1           1
# 127                          0.221068          0            2           1
# 128                          0.400705          0            1           1
#
# [129 rows x 28 columns]

# %%
frame['spectators']
# Out:
# 0       4088799
# 1      12811206
# 2        221925
# 3       1446820
# 4       4300670
# 5       1744677
# 6       1634051
# 7       2945137
# 8       2430200
# 9      12319542
# 10     13019740
# 11      8487894
# 12      1204000
# 13      1914779
# 14       336065
# 15      1130638
# 16       717618
# 17       767657
# 18       699973
# 19      3051134
# 20       434877
# 21      2058764
# 22       561803
# 23      2197555
# 24      4057546
# 25      4662822
# 26     12983330
# 27       199151
# 28      4937573
# 29      1879501
#          ...
# 99      4044582
# 100     2251491
# 101     2393086
# 102     5507106
# 103     1025928
# 104     1914941
# 105      402117
# 106      674933
# 107      178434
# 108      321654
# 109     1437549
# 110     1531220
# 111     1263835
# 112       73132
# 113     1095119
# 114       62788
# 115      678930
# 116        1600
# 117      197678
# 118     6847777
# 119    11746135
# 120       20885
# 121     1694637
# 122      510604
# 123      123633
# 124     2274995
# 125      544656
# 126     1458896
# 127      616654
# 128     1972377
# Name: spectators, dtype: int64

# %%
diameter_counts = frame['diameter'].value_counts()

# %%
diameter_counts
# Out:
# 3    83
# 4    27
# 2    15
# 5     3
# 6     1
# dtype: int64

# %%
# %matplotlib inline

# %%
diameter_counts.plot(kind='barh', rot=0)

# %%
import random
import math
import mysql.connector
import sys
reload(sys)


####DB CONNECT####
cnx=mysql.connector.connect(user='root',password='link#1234',database='9th',host='218.150.181.131',port=3306)
cursor = cnx.cursor()
select = ("SELECT  spectators,name,id,pathlength,clustering,density FROM movies ORDER BY spectators DESC")
cursor.execute(select)
movieTuple = cursor.fetchall()


movieListAtList = []
i=0
while(i<len(movieTuple)):
    movieList = list(movieTuple[i])
    movieListAtList.append(movieList)
    i=i+1

i=0
while(i<len(movieTuple)):
    print movieListAtList[i]
    i=i+1
cnx.commit()
cursor.close()
cnx.close()
#####################


NUM_CLUSTERS = 5
TOTAL_DATA = len(movieTuple)
LOWEST_SAMPLE_POINT = 0 #element 0 of movieListAtList.
HIGHEST_SAMPLE_POINT = 63 #element 3 of movieListAtList.
MID_SAMPLE_POINT = 128
MID2 = 23
MID3 = 80
BIG_NUMBER = math.pow(10, 10)


data = []
centroids = []

class DataPoint:
    def __init__(self,spectators, name,idx,x, y,z):
        self.spectators = spectators
        self.name = name
        self.id = idx
        self.x = x
        self.y = y
        self.z = z
    def set_spectators(self, spectators):
        self.spectators = spectators
    
    def get_spectators(self):
        return self.spectators
    def set_name(self, name):
        self.name = name
    
    def get_name(self):
        return self.name

    def set_id(self, idx):
        self.id = idx
    
    def get_id(self):
        return self.id
    
    def set_x(self, x):
        self.x = x
    
    def get_x(self):
        return self.x
    
    def set_y(self, y):
        self.y = y
    
    def get_y(self):
        return self.y

    def set_z(self, z):
        self.z = z
    
    def get_z(self):
        return self.z
    
    def set_cluster(self, clusterNumber):
        self.clusterNumber = clusterNumber
    
    def get_cluster(self):
        return self.clusterNumber

class Centroid:
    def __init__(self, x, y,z):

        self.x = x
        self.y = y
        self.z = z
    
    def set_x(self, x):
        self.x = x
    
    def get_x(self):
        return self.x
    
    def set_y(self, y):
        self.y = y
    
    def get_y(self):
        return self.y

    def set_z(self, z):
        self.z = z
    
    def get_z(self):
        return self.z

def initialize_centroids():
    # Set the centoid coordinates to match the data points furthest from each other.
    # In this example, (1.0, 1.0) and (5.0, 7.0)
    centroids.append(Centroid(movieListAtList[LOWEST_SAMPLE_POINT][3], movieListAtList[LOWEST_SAMPLE_POINT][4], movieListAtList[LOWEST_SAMPLE_POINT][5]))
    centroids.append(Centroid(movieListAtList[HIGHEST_SAMPLE_POINT][3], movieListAtList[HIGHEST_SAMPLE_POINT][4], movieListAtList[HIGHEST_SAMPLE_POINT][5]))

    centroids.append(Centroid(movieListAtList[MID_SAMPLE_POINT][3], movieListAtList[MID_SAMPLE_POINT][4], movieListAtList[MID_SAMPLE_POINT][5]))
    centroids.append(Centroid(movieListAtList[MID2][3], movieListAtList[MID2][4], movieListAtList[MID2][5]))
    centroids.append(Centroid(movieListAtList[MID3][3], movieListAtList[MID3][4], movieListAtList[MID3][5]))
    
    print("Centroids initialized at:")
    print("(", centroids[0].get_x(), ", ", centroids[0].get_y(), ",",centroids[0].get_z(),")")
    print("(", centroids[1].get_x(), ", ", centroids[1].get_y(), ",",centroids[1].get_z(),")")
    print("(", centroids[2].get_x(), ", ", centroids[2].get_y(), ",",centroids[2].get_z(),")")
    print("(", centroids[3].get_x(), ", ", centroids[3].get_y(), ",",centroids[3].get_z(),")")
    print("(", centroids[4].get_x(), ", ", centroids[4].get_y(), ",",centroids[4].get_z(),")")
    print()
    return

def initialize_datapoints():
    # DataPoint objects' x and y values are taken from the SAMPLE array.
    # The DataPoints associated with LOWEST_SAMPLE_POINT and HIGHEST_SAMPLE_POINT are initially
    # assigned to the clusters matching the LOWEST_SAMPLE_POINT and HIGHEST_SAMPLE_POINT centroids.
    for i in range(TOTAL_DATA):
        newPoint = DataPoint(movieListAtList[i][0],movieListAtList[i][1], movieListAtList[i][2],movieListAtList[i][3],movieListAtList[i][4],movieListAtList[i][5])

        
        if(i == LOWEST_SAMPLE_POINT):
            newPoint.set_cluster(0)
        elif(i == HIGHEST_SAMPLE_POINT):
            newPoint.set_cluster(1)
        elif(i == MID_SAMPLE_POINT):
            newPoint.set_cluster(2)
        elif(i == MID2):
            newPoint.set_cluster(3)
        elif(i == MID3):
            newPoint.set_cluster(4)
        else:
            newPoint.set_cluster(None)
            
        data.append(newPoint)
       

    
    return

def get_distance(dataPointX, dataPointY, dataPointZ, centroidX, centroidY, centroidZ):
    # Calculate Euclidean distance.
    return math.sqrt(math.pow((centroidY - dataPointY), 2) + math.pow((centroidX - dataPointX), 2) + math.pow((centroidZ - dataPointZ), 2))

def recalculate_centroids():
    totalX = 0
    totalY = 0
    totalZ = 0
    totalInCluster = 0
    
    for j in range(NUM_CLUSTERS):
        for k in range(len(data)):
            if(data[k].get_cluster() == j):
                totalX += data[k].get_x()
                totalY += data[k].get_y()
                totalZ += data[k].get_z()
                totalInCluster += 1
        
        if(totalInCluster > 0):
            print j
            centroids[j].set_x(totalX / totalInCluster)
            centroids[j].set_y(totalY / totalInCluster)
            centroids[j].set_z(totalZ / totalInCluster)
    
    return

def update_clusters():
    isStillMoving = 0
    
    for i in range(TOTAL_DATA):
        bestMinimum = BIG_NUMBER
        currentCluster = 0
        
        for j in range(NUM_CLUSTERS):
            distance = get_distance(data[i].get_x(), data[i].get_y(),  data[i].get_z(), centroids[j].get_x(), centroids[j].get_y(), centroids[j].get_z() )
            if(distance < bestMinimum):
                bestMinimum = distance
                currentCluster = j
        
        data[i].set_cluster(currentCluster)
        
        if(data[i].get_cluster() is None or data[i].get_cluster() != currentCluster):
            data[i].set_cluster(currentCluster)
            isStillMoving = 1
    
    return isStillMoving

def perform_kmeans():
    isStillMoving = 1
    
    initialize_centroids()
    
    initialize_datapoints()
    
    while(isStillMoving):
        recalculate_centroids()
        isStillMoving = update_clusters()
    
    return

def print_results():
    for i in range(NUM_CLUSTERS):
        print("Cluster ", i, " includes:")
        for j in range(TOTAL_DATA):
            if(data[j].get_cluster() == i):
                print("(", data[j].get_id(), ",", data[j].get_x(), ", ", data[j].get_y(),  ", ", data[j].get_z(),")")
        print()
    for i in range(NUM_CLUSTERS):
        print("Cluster ", i, " includes:")
        for j in range(TOTAL_DATA):
            if(data[j].get_cluster() == i):
                print data[j].get_name(), ",", data[j].get_spectators()
        print()    
    
    return

perform_kmeans()
print_results()

# %%
print data[1].get_name()

# %%
import sys
print sys.stdout
# Out:
# <IPython.kernel.zmq.iostream.OutStream object at 0x1035977d0>

# %%
import random
import math
import mysql.connector



####DB CONNECT####
cnx=mysql.connector.connect(user='root',password='link#1234',database='9th',host='218.150.181.131',port=3306)
cursor = cnx.cursor()
select = ("SELECT  spectators,name,id,pathlength,clustering,density FROM movies ORDER BY spectators DESC")
cursor.execute(select)
movieTuple = cursor.fetchall()


movieListAtList = []
i=0
while(i<len(movieTuple)):
    movieList = list(movieTuple[i])
    movieListAtList.append(movieList)
    i=i+1
cnx.commit()
cursor.close()
cnx.close()
#####################


NUM_CLUSTERS = 5
TOTAL_DATA = len(movieTuple)
LOWEST_SAMPLE_POINT = 0 #element 0 of movieListAtList.
HIGHEST_SAMPLE_POINT = 63 #element 3 of movieListAtList.
MID_SAMPLE_POINT = 128
MID2 = 23
MID3 = 80
BIG_NUMBER = math.pow(10, 10)


data = []
centroids = []

class DataPoint:
    def __init__(self,spectators, name,idx,x, y,z):
        self.spectators = spectators
        self.name = name
        self.id = idx
        self.x = x
        self.y = y
        self.z = z
    def set_spectators(self, spectators):
        self.spectators = spectators
    
    def get_spectators(self):
        return self.spectators
    def set_name(self, name):
        self.name = name
    
    def get_name(self):
        return self.name

    def set_id(self, idx):
        self.id = idx
    
    def get_id(self):
        return self.id
    
    def set_x(self, x):
        self.x = x
    
    def get_x(self):
        return self.x
    
    def set_y(self, y):
        self.y = y
    
    def get_y(self):
        return self.y

    def set_z(self, z):
        self.z = z
    
    def get_z(self):
        return self.z
    
    def set_cluster(self, clusterNumber):
        self.clusterNumber = clusterNumber
    
    def get_cluster(self):
        return self.clusterNumber

class Centroid:
    def __init__(self, x, y,z):

        self.x = x
        self.y = y
        self.z = z
    
    def set_x(self, x):
        self.x = x
    
    def get_x(self):
        return self.x
    
    def set_y(self, y):
        self.y = y
    
    def get_y(self):
        return self.y

    def set_z(self, z):
        self.z = z
    
    def get_z(self):
        return self.z

def initialize_centroids():
    # Set the centoid coordinates to match the data points furthest from each other.
    # In this example, (1.0, 1.0) and (5.0, 7.0)
    centroids.append(Centroid(movieListAtList[LOWEST_SAMPLE_POINT][3], movieListAtList[LOWEST_SAMPLE_POINT][4], movieListAtList[LOWEST_SAMPLE_POINT][5]))
    centroids.append(Centroid(movieListAtList[HIGHEST_SAMPLE_POINT][3], movieListAtList[HIGHEST_SAMPLE_POINT][4], movieListAtList[HIGHEST_SAMPLE_POINT][5]))

    centroids.append(Centroid(movieListAtList[MID_SAMPLE_POINT][3], movieListAtList[MID_SAMPLE_POINT][4], movieListAtList[MID_SAMPLE_POINT][5]))
    centroids.append(Centroid(movieListAtList[MID2][3], movieListAtList[MID2][4], movieListAtList[MID2][5]))
    centroids.append(Centroid(movieListAtList[MID3][3], movieListAtList[MID3][4], movieListAtList[MID3][5]))
    
    print("Centroids initialized at:")
    print("(", centroids[0].get_x(), ", ", centroids[0].get_y(), ",",centroids[0].get_z(),")")
    print("(", centroids[1].get_x(), ", ", centroids[1].get_y(), ",",centroids[1].get_z(),")")
    print("(", centroids[2].get_x(), ", ", centroids[2].get_y(), ",",centroids[2].get_z(),")")
    print("(", centroids[3].get_x(), ", ", centroids[3].get_y(), ",",centroids[3].get_z(),")")
    print("(", centroids[4].get_x(), ", ", centroids[4].get_y(), ",",centroids[4].get_z(),")")
    print()
    return

def initialize_datapoints():
    # DataPoint objects' x and y values are taken from the SAMPLE array.
    # The DataPoints associated with LOWEST_SAMPLE_POINT and HIGHEST_SAMPLE_POINT are initially
    # assigned to the clusters matching the LOWEST_SAMPLE_POINT and HIGHEST_SAMPLE_POINT centroids.
    for i in range(TOTAL_DATA):
        newPoint = DataPoint(movieListAtList[i][0],movieListAtList[i][1], movieListAtList[i][2],movieListAtList[i][3],movieListAtList[i][4],movieListAtList[i][5])

        
        if(i == LOWEST_SAMPLE_POINT):
            newPoint.set_cluster(0)
        elif(i == HIGHEST_SAMPLE_POINT):
            newPoint.set_cluster(1)
        elif(i == MID_SAMPLE_POINT):
            newPoint.set_cluster(2)
        elif(i == MID2):
            newPoint.set_cluster(3)
        elif(i == MID3):
            newPoint.set_cluster(4)
        else:
            newPoint.set_cluster(None)
            
        data.append(newPoint)
       

    
    return

def get_distance(dataPointX, dataPointY, dataPointZ, centroidX, centroidY, centroidZ):
    # Calculate Euclidean distance.
    return math.sqrt(math.pow((centroidY - dataPointY), 2) + math.pow((centroidX - dataPointX), 2) + math.pow((centroidZ - dataPointZ), 2))

def recalculate_centroids():
    totalX = 0
    totalY = 0
    totalZ = 0
    totalInCluster = 0
    
    for j in range(NUM_CLUSTERS):
        for k in range(len(data)):
            if(data[k].get_cluster() == j):
                totalX += data[k].get_x()
                totalY += data[k].get_y()
                totalZ += data[k].get_z()
                totalInCluster += 1
        
        if(totalInCluster > 0):
            centroids[j].set_x(totalX / totalInCluster)
            centroids[j].set_y(totalY / totalInCluster)
            centroids[j].set_z(totalZ / totalInCluster)
    
    return

def update_clusters():
    isStillMoving = 0
    
    for i in range(TOTAL_DATA):
        bestMinimum = BIG_NUMBER
        currentCluster = 0
        
        for j in range(NUM_CLUSTERS):
            distance = get_distance(data[i].get_x(), data[i].get_y(),  data[i].get_z(), centroids[j].get_x(), centroids[j].get_y(), centroids[j].get_z() )
            if(distance < bestMinimum):
                bestMinimum = distance
                currentCluster = j
        
        data[i].set_cluster(currentCluster)
        
        if(data[i].get_cluster() is None or data[i].get_cluster() != currentCluster):
            data[i].set_cluster(currentCluster)
            isStillMoving = 1
    
    return isStillMoving

def perform_kmeans():
    isStillMoving = 1
    
    initialize_centroids()
    
    initialize_datapoints()
    
    while(isStillMoving):
        recalculate_centroids()
        isStillMoving = update_clusters()
    
    return

def print_results():
    for i in range(NUM_CLUSTERS):
        print("Cluster ", i, " includes:")
        for j in range(TOTAL_DATA):
            if(data[j].get_cluster() == i):
                print data[j].get_name(), ",", data[j].get_spectators()
        print()    
    
    return

perform_kmeans()
print_results()
# Out:
# Centroids initialized at:
# ('(', 1.418462, ', ', 0.128901, ',', 0.590769, ')')
# ('(', 1.714286, ', ', 0.202397, ',', 0.285714, ')')
# ('(', 1.721053, ', ', 0.10139, ',', 0.326316, ')')
# ('(', 1.822134, ', ', 0.132806, ',', 0.264822, ')')
# ('(', 1.75641, ', ', 0.081473, ',', 0.397436, ')')
# ()
# ('Cluster ', 0, ' includes:')
# 명량 , 17611849
# 도둑들 , 12983330
# 마파도 , 3090467
# 베스트셀러 , 1099665
# 싸이보그지만괜찮아 , 739481
# 스승의은혜 , 629452
# 애정결핍이두남자에게미치는영향 , 593277
# 미술관옆동물원 , 412472
# 해안선 , 123633
# ()
# ('Cluster ', 1, ' includes:')
# 국가대표 , 8487894
# 맨발의기봉이 , 2347311
# 혈의누 , 2274995
# 박쥐 , 2237271
# 고사 , 1634051
# 그녀를믿지마세요 , 1204000
# 지금사랑하는사람과살고있습니까 , 1095119
# 플라이대디 , 510604
# 도레미파솔라시도 , 199151
# ()
# ('Cluster ', 2, ' includes:')
# 설국열차 , 9350194
# 말아톤 , 5148022
# 광식이동생광태 , 2430200
# 아라한장풍대작전 , 2050000
# 멋진하루 , 390741
# 첼로홍미주일가살인사건 , 197678
# 아내의애인을만나다 , 6999
# ()
# ('Cluster ', 3, ' includes:')
# 홀리데이 , 1458896
# 주홍글씨 , 1437549
# 달콤한인생 , 1271595
# 숙명 , 858215
# 부산 , 160741
# ()
# ('Cluster ', 4, ' includes:')
# 괴물 , 13019740
# 7번방의선물 , 12811206
# 광해 , 12319542
# 왕의남자 , 12302831
# 태극기휘날리며 , 11746135
# 실미도 , 11081000
# 써니 , 7328820
# 타짜 , 6847777
# 미녀는괴로워 , 6619498
# 아저씨 , 6282774
# 쉬리 , 5820000
# 의형제 , 5507106
# 완득이 , 5310510
# 살인의추억 , 5255376
# 동갑내기과외하기 , 4937573
# 신세계 , 4682492
# 도가니 , 4662822
# 연가시 , 4513026
# 강철중 , 4300670
# 7급공무원 , 4088799
# 댄싱퀸 , 4057546
# 우리생애최고의순간 , 4044582
# 스캔들 , 3522747
# 올드보이 , 3269000
# 말죽거리잔혹사 , 3115767
# 너는내운명 , 3051134
# 마더 , 3013523
# 고지전 , 2945137
# 반창고 , 2475797
# 의뢰인 , 2393086
# 위대한유산 , 2251491
# 댄서의순정 , 2197555
# 바르게살자 , 2190250
# 범죄의재구성 , 2129358
# 사랑 , 2123815
# 눈에는눈이에는이 , 2058764
# 효자동이발사 , 1972377
# 잠복근무 , 1914941
# 그림자살인 , 1914779
# 라디오스타 , 1879501
# 악마를보았다 , 1848418
# 거룩한계보 , 1744677
# 러브픽션 , 1726202
# 밀양 , 1710364
# 품행제로 , 1694637
# 중천 , 1531220
# 각설탕 , 1446820
# 역도산 , 1386179
# 만남의광장 , 1306434
# 즐거운인생 , 1263835
# 미스터소크라테스 , 1261965
# 신부수업 , 1242476
# 김종욱찾기 , 1130638
# 오해피데이 , 1073230
# 수상한고객들 , 1059350
# 이중간첩 , 1025928
# 오로라공주 , 946372
# 영어완전정복 , 917782
# 마이파더 , 902090
# 마린보이 , 837059
# 슈퍼스타감사용 , 834706
# 나의결혼원정기 , 767657
# 꽃피는봄이오면 , 717618
# 약속 , 704600
# 내깡패같은애인 , 699973
# 천하장사마돈나 , 678930
# 접속 , 674933
# 아파트 , 644893
# 홍길동의후예 , 616654
# 열혈남아 , 570059
# 다세포소녀 , 561803
# 사랑따윈필요없어 , 548998
# 호로비츠를위하여 , 544656
# 얼굴없는미녀 , 520753
# 아이스케키 , 516492
# 누가그녀와잤을까 , 434877
# 미스터주부퀴즈왕 , 413157
# 사랑해말순씨 , 406526
# 전설의고향 , 402117
# 마들렌 , 365656
# 그해여름 , 336065
# 좋지아니한가 , 321654
# 스카우트 , 315187
# 박하사탕 , 290352
# 소년천국에가다 , 242053
# 시 , 222017
# 가족의탄생 , 221925
# 세븐데이즈 , 212074
# 조용한세상 , 178434
# 마을금고연쇄습격사건 , 123770
# 와니와준하 , 100400
# 우리동네 , 77591
# 지구를지켜라 , 73132
# 브라보마이라이프 , 73034
# 질투는나의힘 , 62788
# 우리들의일그러진영웅 , 32359
# 파수꾼 , 20885
# 청포도사탕 , 1600
# 오버더레인보우 , 0
# ()
